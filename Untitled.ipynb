# %%
import logging
import pandas as pd
from sodapy import Socrata
import pymongo
import expiringdict
import utils
logger = logging.Logger(__name__)
utils.setup_logger(logger, 'db.log')

client = Socrata("data.lacity.org", None)
results = client.get("yru6-6re4",where="arst_date == '2019-11-08T00:00:00.000'") # wait to be confirmed
df = pd.DataFrame.from_records(results)
df['arst_date'] = pd.to_datetime(df['arst_date'])
clientm = pymongo.MongoClient()
db = clientm.get_database("crime")
collection = db.get_collection("crime")
update_count = 0
for record in df.to_dict('records'):
    result = collection.replace_one(
        filter = {'rpt_id': record['rpt_id']},    # locate the document if exists
        replacement = record,                         # latest document
        upsert=True)
    if result.matched_count > 0:
            update_count += 1
    logger.info("rows={}, update={}, ".format(df.shape[0], update_count) +
                "insert={}".format(df.shape[0]-update_count))
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# 2019-12-12 21:59:23,837 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,839 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,843 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,846 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,849 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,851 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,853 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,855 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,857 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,859 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,863 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,865 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,867 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,871 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,873 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,875 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,877 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,879 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,881 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,883 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,885 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,887 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,889 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,891 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,894 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,895 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,898 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,900 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,902 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,904 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,906 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,908 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,910 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,913 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,915 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,917 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,919 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,921 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,923 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,924 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,926 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,928 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,931 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,933 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,935 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,937 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,941 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,943 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,945 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,947 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,949 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,951 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,953 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,955 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,957 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,959 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,961 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,963 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,965 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,967 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,970 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,972 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,975 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,977 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,979 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,981 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,983 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,985 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,987 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,990 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,992 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,994 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,996 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:23,998 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,000 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,002 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,004 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,006 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,008 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,010 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,013 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,015 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,017 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,020 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,022 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,024 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,026 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,028 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,030 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,032 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,035 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,037 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,039 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,042 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,044 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,046 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,048 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,050 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,053 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,055 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,058 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,060 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,062 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,064 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,066 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,068 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,070 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,072 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,074 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,076 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,078 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,080 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,082 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,084 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,086 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,088 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,090 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,092 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,094 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,097 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,099 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,101 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,103 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,105 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,108 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,110 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,112 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,114 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,116 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,118 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,120 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,123 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,125 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,127 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,129 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,132 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,134 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,136 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,139 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,141 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,143 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,145 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,147 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,154 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,156 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,159 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,161 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,165 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,168 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,171 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,174 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,176 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,178 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,181 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,183 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,185 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,187 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,191 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,193 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,196 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,199 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,201 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,203 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,206 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,208 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,210 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,211 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,213 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,215 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,217 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,219 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,221 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,224 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,226 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,228 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,230 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,232 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,234 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,236 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,239 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,241 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,243 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,245 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,247 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,250 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,252 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,254 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,256 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,258 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,261 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,263 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,266 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,268 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,270 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,272 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,275 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,277 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,279 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,281 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,283 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,285 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,288 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,290 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,292 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,294 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,296 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,298 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,300 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,302 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,304 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,306 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,310 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,312 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,314 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,316 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,318 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,320 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,322 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,324 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,326 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,329 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,331 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,334 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,336 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,338 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,340 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,343 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,348 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,351 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,353 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,356 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,358 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,360 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,362 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,364 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,366 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,369 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,371 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,373 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,375 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,377 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,380 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,382 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,384 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,386 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,389 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,391 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,393 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,395 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,398 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,401 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,404 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,408 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,412 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,414 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,417 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,420 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,422 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,424 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,426 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,428 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,430 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,432 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,434 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,437 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,439 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,441 [<module>]: rows=268, update=0, insert=268
# 2019-12-12 21:59:24,443 [<module>]: rows=268, update=0, insert=268

# %%
db = clientm.get_database("crime")
collection = db.get_collection("crime")
ret = list(collection.find())
logger.info(str(len(ret)) + ' documents read from the db')
ret
# Out:
# 2019-12-12 21:59:30,513 [<module>]: 1258 documents read from the db
# [{'_id': ObjectId('5df2b14e303caffad1596065'),
#   'rpt_id': '190819078',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '1300',
#   'area': '08',
#   'area_desc': 'West LA',
#   'rd': '0817',
#   'age': '30',
#   'sex_cd': 'M',
#   'descent_cd': 'O',
#   'chrg_grp_cd': nan,
#   'grp_description': nan,
#   'arst_typ_cd': 'M',
#   'charge': '308(A)1PC',
#   'chrg_desc': nan,
#   'location': '900    WESTWOOD                     BL',
#   'crsst': nan,
#   'location_1': {'latitude': '34.0637',
#    'longitude': '-118.4453',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b14f303caffad159611e'),
#   'rpt_id': '5812713',
#   'arst_date': datetime.datetime(2019, 12, 2, 0, 0),
#   'time': '0930',
#   'area': '15',
#   'area_desc': 'N Hollywood',
#   'rd': '1523',
#   'age': '54',
#   'sex_cd': 'M',
#   'descent_cd': 'O',
#   'chrg_grp_cd': '04',
#   'grp_description': 'Aggravated Assault',
#   'arst_typ_cd': 'F',
#   'charge': '245(A)(1)PC',
#   'chrg_desc': 'ADW, NOT FIREARM, W/GBI',
#   'location': '6300    TEESDALE                     AV',
#   'crsst': nan,
#   'location_1': {'latitude': '34.1849',
#    'longitude': '-118.4084',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b14f303caffad15961e8'),
#   'rpt_id': '191120321',
#   'arst_date': datetime.datetime(2019, 12, 3, 0, 0),
#   'time': '1450',
#   'area': '11',
#   'area_desc': 'Northeast',
#   'rd': '1105',
#   'age': '59',
#   'sex_cd': 'M',
#   'descent_cd': 'W',
#   'chrg_grp_cd': nan,
#   'grp_description': nan,
#   'arst_typ_cd': 'M',
#   'charge': '11364',
#   'chrg_desc': nan,
#   'location': 'BROADWAY',
#   'crsst': 'VERANO',
#   'location_1': {'latitude': '34.1442',
#    'longitude': '-118.218',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b14f303caffad15962c7'),
#   'rpt_id': '5814534',
#   'arst_date': datetime.datetime(2019, 12, 4, 0, 0),
#   'time': '1140',
#   'area': '03',
#   'area_desc': 'Southwest',
#   'rd': '0311',
#   'age': '21',
#   'sex_cd': 'M',
#   'descent_cd': 'B',
#   'chrg_grp_cd': '14',
#   'grp_description': 'Sex (except rape/prst)',
#   'arst_typ_cd': 'M',
#   'charge': '647(A)PC',
#   'chrg_desc': 'SOLICIT/ENGAGE LEWD ACT IN PUBLIC VIEW',
#   'location': '3200 S  LA CIENEGA                   BL',
#   'crsst': nan,
#   'location_1': {'latitude': '34.0293',
#    'longitude': '-118.3719',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b14f303caffad1596344'),
#   'rpt_id': '5792472',
#   'arst_date': datetime.datetime(2019, 12, 5, 0, 0),
#   'time': '1700',
#   'area': '12',
#   'area_desc': '77th Street',
#   'rd': '1258',
#   'age': '46',
#   'sex_cd': 'M',
#   'descent_cd': 'B',
#   'chrg_grp_cd': '01',
#   'grp_description': 'Homicide',
#   'arst_typ_cd': 'F',
#   'charge': '187(A)PC',
#   'chrg_desc': 'MURDER:FIRST DEGREE:SHOOT FROM VEHICLE',
#   'location': '7600 S  BROADWAY',
#   'crsst': nan,
#   'location_1': {'latitude': '33.9708',
#    'longitude': '-118.2783',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b14f303caffad15963d3'),
#   'rpt_id': '5816348',
#   'arst_date': datetime.datetime(2019, 12, 6, 0, 0),
#   'time': '1749',
#   'area': '20',
#   'area_desc': 'Olympic',
#   'rd': '2017',
#   'age': '46',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '22',
#   'grp_description': 'Driving Under Influence',
#   'arst_typ_cd': 'M',
#   'charge': '23152(A)VC',
#   'chrg_desc': 'DRUNK DRIVING ALCOHOL/DRUGS',
#   'location': 'OAKWOOD                      AV',
#   'crsst': 'VERMONT                      AV',
#   'location_1': {'latitude': '34.0709',
#    'longitude': '-118.2941',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b14f303caffad159642d'),
#   'rpt_id': '5816829',
#   'arst_date': datetime.datetime(2019, 12, 7, 0, 0),
#   'time': '0354',
#   'area': '01',
#   'area_desc': 'Central',
#   'rd': '0135',
#   'age': '55',
#   'sex_cd': 'F',
#   'descent_cd': 'B',
#   'chrg_grp_cd': '22',
#   'grp_description': 'Driving Under Influence',
#   'arst_typ_cd': 'M',
#   'charge': '23152(A)VC',
#   'chrg_desc': 'DRUNK DRIVING ALCOHOL/DRUGS',
#   'location': '10                           FY',
#   'crsst': '51ST                         ST',
#   'location_1': {'latitude': '34.0495',
#    'longitude': '-118.2458',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad159692b'),
#   'rpt_id': '5811793',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '0311',
#   'area': '15',
#   'area_desc': 'N Hollywood',
#   'rd': '1565',
#   'age': '26',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '22',
#   'grp_description': 'Driving Under Influence',
#   'arst_typ_cd': 'M',
#   'charge': '23152(A)VC',
#   'chrg_desc': 'DRUNK DRIVING ALCOHOL/DRUGS',
#   'location': 'VINELAND                     AV',
#   'crsst': 'HOLLYWOOD                    FY',
#   'location_1': {'latitude': '34.1468',
#    'longitude': '-118.3703',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad159692d'),
#   'rpt_id': '5811921',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '0300',
#   'area': '13',
#   'area_desc': 'Newton',
#   'rd': '1307',
#   'age': '21',
#   'sex_cd': 'M',
#   'descent_cd': 'B',
#   'chrg_grp_cd': '04',
#   'grp_description': 'Aggravated Assault',
#   'arst_typ_cd': 'F',
#   'charge': '245(D)(1)PC',
#   'chrg_desc': 'ASSAULT W/FIREARM ON PO OR FIREMAN',
#   'location': '700    CROCKER                      ST',
#   'crsst': nan,
#   'location_1': {'latitude': '34.0401',
#    'longitude': '-118.2459',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad159692f'),
#   'rpt_id': '5812227',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '1540',
#   'area': '13',
#   'area_desc': 'Newton',
#   'rd': '1362',
#   'age': '28',
#   'sex_cd': 'M',
#   'descent_cd': 'B',
#   'chrg_grp_cd': '05',
#   'grp_description': 'Burglary',
#   'arst_typ_cd': 'F',
#   'charge': '459PC',
#   'chrg_desc': 'BURGLARY',
#   'location': '400 E  49TH                         ST',
#   'crsst': nan,
#   'location_1': {'latitude': '33.9988',
#    'longitude': '-118.2696',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad1596931'),
#   'rpt_id': '190920652',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '0225',
#   'area': '09',
#   'area_desc': 'Van Nuys',
#   'rd': '0914',
#   'age': '45',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '13',
#   'grp_description': 'Prostitution/Allied',
#   'arst_typ_cd': 'M',
#   'charge': '647(B)(2)PC',
#   'chrg_desc': 'ENGAGE/SOLICIT SEX FOR MONEY/ETC',
#   'location': 'SEPULVEDA                    BL',
#   'crsst': 'HART                         ST',
#   'location_1': {'latitude': '34.1976',
#    'longitude': '-118.4662',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad1596933'),
#   'rpt_id': '5812327',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '2015',
#   'area': '06',
#   'area_desc': 'Hollywood',
#   'rd': '0646',
#   'age': '39',
#   'sex_cd': 'M',
#   'descent_cd': 'B',
#   'chrg_grp_cd': '03',
#   'grp_description': 'Robbery',
#   'arst_typ_cd': 'F',
#   'charge': '211PC',
#   'chrg_desc': 'ROBBERY',
#   'location': 'COSMO',
#   'crsst': 'HOLLYWOOD                    BL',
#   'location_1': {'latitude': '34.1016',
#    'longitude': '-118.3288',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad1596935'),
#   'rpt_id': '190800808',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '1210',
#   'area': '08',
#   'area_desc': 'West LA',
#   'rd': '0892',
#   'age': '57',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '16',
#   'grp_description': 'Narcotic Drug Laws',
#   'arst_typ_cd': 'M',
#   'charge': '11364HS',
#   'chrg_desc': 'POSSESSION CNTL SUBSTANCE PARAPHERNALIA',
#   'location': 'SEPULVEDA                    BL',
#   'crsst': 'PICO                         BL',
#   'location_1': {'latitude': '34.0321',
#    'longitude': '-118.4399',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad1596937'),
#   'rpt_id': '191521480',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '0845',
#   'area': '15',
#   'area_desc': 'N Hollywood',
#   'rd': '1547',
#   'age': '49',
#   'sex_cd': 'M',
#   'descent_cd': 'W',
#   'chrg_grp_cd': nan,
#   'grp_description': nan,
#   'arst_typ_cd': 'I',
#   'charge': '4145',
#   'chrg_desc': nan,
#   'location': 'TUJUNGA',
#   'crsst': 'CHANDLER',
#   'location_1': {'latitude': '34.1689',
#    'longitude': '-118.379',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad1596939'),
#   'rpt_id': '190518841',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '1130',
#   'area': '05',
#   'area_desc': 'Harbor',
#   'rd': '0563',
#   'age': '35',
#   'sex_cd': 'M',
#   'descent_cd': 'W',
#   'chrg_grp_cd': '24',
#   'grp_description': 'Miscellaneous Other Violations',
#   'arst_typ_cd': 'M',
#   'charge': '308(A)PC',
#   'chrg_desc': 'GIVE TOBACCO/SMOKG PARAPHERNALIA MINR <18',
#   'location': '1300 S  GAFFEY                       ST',
#   'crsst': nan,
#   'location_1': {'latitude': '33.7324',
#    'longitude': '-118.2924',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad159693b'),
#   'rpt_id': '5812395',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '1930',
#   'area': '11',
#   'area_desc': 'Northeast',
#   'rd': '1189',
#   'age': '13',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': nan,
#   'grp_description': nan,
#   'arst_typ_cd': 'D',
#   'charge': '300(A)WI',
#   'chrg_desc': nan,
#   'location': '3500    MARMION                      WY',
#   'crsst': nan,
#   'location_1': {'latitude': '34.0871',
#    'longitude': '-118.2142',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad159693d'),
#   'rpt_id': '5811828',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '0405',
#   'area': '09',
#   'area_desc': 'Van Nuys',
#   'rd': '0905',
#   'age': '27',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '16',
#   'grp_description': 'Narcotic Drug Laws',
#   'arst_typ_cd': 'M',
#   'charge': '11377(A)HS',
#   'chrg_desc': 'POSSESSION CONTROLLED SUBSTANCE',
#   'location': '7300    VISTA DEL MONTE              AV',
#   'crsst': nan,
#   'location_1': {'latitude': '34.203',
#    'longitude': '-118.4501',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad159693f'),
#   'rpt_id': '5811878',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '0930',
#   'area': '05',
#   'area_desc': 'Harbor',
#   'rd': '0567',
#   'age': '43',
#   'sex_cd': 'F',
#   'descent_cd': 'O',
#   'chrg_grp_cd': '12',
#   'grp_description': 'Weapon (carry/poss)',
#   'arst_typ_cd': 'M',
#   'charge': '417(A)(1)PC',
#   'chrg_desc': 'EXHIBIT/DRAW DEADLY WEAPON NOT A FIREARM',
#   'location': '2300 S  PACIFIC                      AV',
#   'crsst': nan,
#   'location_1': {'latitude': '33.7234',
#    'longitude': '-118.288',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad1596941'),
#   'rpt_id': '5811836',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '0645',
#   'area': '12',
#   'area_desc': '77th Street',
#   'rd': '1258',
#   'age': '56',
#   'sex_cd': 'M',
#   'descent_cd': 'B',
#   'chrg_grp_cd': '24',
#   'grp_description': 'Miscellaneous Other Violations',
#   'arst_typ_cd': 'F',
#   'charge': '3000.08CPC',
#   'chrg_desc': 'PAROLE WARRANT',
#   'location': '7600 S  BROADWAY',
#   'crsst': nan,
#   'location_1': {'latitude': '33.9708',
#    'longitude': '-118.2783',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad1596943'),
#   'rpt_id': '5812482',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '2330',
#   'area': '06',
#   'area_desc': 'Hollywood',
#   'rd': '0657',
#   'age': '40',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '08',
#   'grp_description': 'Other Assaults',
#   'arst_typ_cd': 'M',
#   'charge': '243(A)PC',
#   'chrg_desc': 'BATTERY ON PERSON',
#   'location': '900 N  WILTON                       PL',
#   'crsst': nan,
#   'location_1': {'latitude': '34.0871',
#    'longitude': '-118.3135',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad1596945'),
#   'rpt_id': '5812293',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '1830',
#   'area': '21',
#   'area_desc': 'Topanga',
#   'rd': '2156',
#   'age': '24',
#   'sex_cd': 'F',
#   'descent_cd': 'W',
#   'chrg_grp_cd': '06',
#   'grp_description': 'Larceny',
#   'arst_typ_cd': 'M',
#   'charge': '488PC',
#   'chrg_desc': 'PETTY THEFT',
#   'location': '21500    VICTORY                      BL',
#   'crsst': nan,
#   'location_1': {'latitude': '34.1882',
#    'longitude': '-118.5988',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad1596947'),
#   'rpt_id': '5811821',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '0505',
#   'area': '02',
#   'area_desc': 'Rampart',
#   'rd': '0245',
#   'age': '46',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '22',
#   'grp_description': 'Driving Under Influence',
#   'arst_typ_cd': 'M',
#   'charge': '23152(A)VC',
#   'chrg_desc': 'DRUNK DRIVING ALCOHOL/DRUGS',
#   'location': 'WILSHIRE',
#   'crsst': 'PARK VIEW',
#   'location_1': {'latitude': '34.0597',
#    'longitude': '-118.2795',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad1596949'),
#   'rpt_id': '5812418',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '1900',
#   'area': '21',
#   'area_desc': 'Topanga',
#   'rd': '2187',
#   'age': '42',
#   'sex_cd': 'M',
#   'descent_cd': 'W',
#   'chrg_grp_cd': '04',
#   'grp_description': 'Aggravated Assault',
#   'arst_typ_cd': 'F',
#   'charge': '273.5(A)PC',
#   'chrg_desc': 'CORPORAL INJURY ON SPOUSE/COHABITANT/ETC',
#   'location': '21000    VENTURA                      BL',
#   'crsst': nan,
#   'location_1': {'latitude': '34.1667',
#    'longitude': '-118.5908',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad159694b'),
#   'rpt_id': '5811987',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '1325',
#   'area': '09',
#   'area_desc': 'Van Nuys',
#   'rd': '0905',
#   'age': '20',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '16',
#   'grp_description': 'Narcotic Drug Laws',
#   'arst_typ_cd': 'F',
#   'charge': '11379(A)HS',
#   'chrg_desc': 'TRANSPORT/SELL CONTROLLED SUBSTANCE',
#   'location': 'VISTA DEL MONTE',
#   'crsst': 'RUNNYMEDE                    ST',
#   'location_1': {'latitude': '34.2058',
#    'longitude': '-118.45',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad159694d'),
#   'rpt_id': '5812349',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '2100',
#   'area': '06',
#   'area_desc': 'Hollywood',
#   'rd': '0636',
#   'age': '20',
#   'sex_cd': 'M',
#   'descent_cd': 'B',
#   'chrg_grp_cd': '04',
#   'grp_description': 'Aggravated Assault',
#   'arst_typ_cd': 'F',
#   'charge': '273.5(A)PC',
#   'chrg_desc': 'CORPORAL INJURY ON SPOUSE/COHABITANT/ETC',
#   'location': '1700 N  HIGHLAND                     AV',
#   'crsst': nan,
#   'location_1': {'latitude': '34.1016',
#    'longitude': '-118.3387',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad159694f'),
#   'rpt_id': '190920624',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '1230',
#   'area': '09',
#   'area_desc': 'Van Nuys',
#   'rd': '0985',
#   'age': '27',
#   'sex_cd': 'M',
#   'descent_cd': 'W',
#   'chrg_grp_cd': '20',
#   'grp_description': 'Disorderly Conduct',
#   'arst_typ_cd': 'M',
#   'charge': '647(C)PC',
#   'chrg_desc': 'BEGGING',
#   'location': 'VENTURA',
#   'crsst': 'HAZELTINE                    AV',
#   'location_1': {'latitude': '34.1557',
#    'longitude': '-118.44',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad1596951'),
#   'rpt_id': '5812323',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '1802',
#   'area': '09',
#   'area_desc': 'Van Nuys',
#   'rd': '0964',
#   'age': '36',
#   'sex_cd': 'F',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '06',
#   'grp_description': 'Larceny',
#   'arst_typ_cd': 'M',
#   'charge': '459.5PC',
#   'chrg_desc': 'SHOPLIFTING',
#   'location': '14000    RIVERSIDE                    DR',
#   'crsst': nan,
#   'location_1': {'latitude': '34.1576',
#    'longitude': '-118.438',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad1596953'),
#   'rpt_id': '5811857',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '0339',
#   'area': '14',
#   'area_desc': 'Pacific',
#   'rd': '1436',
#   'age': '23',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '22',
#   'grp_description': 'Driving Under Influence',
#   'arst_typ_cd': 'M',
#   'charge': '23152(A)VC',
#   'chrg_desc': 'DRUNK DRIVING ALCOHOL/DRUGS',
#   'location': '405',
#   'crsst': 'PALMS                        BL',
#   'location_1': {'latitude': '34.0152',
#    'longitude': '-118.4217',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad1596955'),
#   'rpt_id': '5812275',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '1500',
#   'area': '07',
#   'area_desc': 'Wilshire',
#   'rd': '0701',
#   'age': '42',
#   'sex_cd': 'M',
#   'descent_cd': 'B',
#   'chrg_grp_cd': '10',
#   'grp_description': 'Fraud/Embezzlement',
#   'arst_typ_cd': 'F',
#   'charge': '332(A)PC',
#   'chrg_desc': 'OBTAIN OVER $400 BY FRAUD/TRICK',
#   'location': 'FAIRFAX',
#   'crsst': 'ROSEWOOD',
#   'location_1': {'latitude': '34.0802',
#    'longitude': '-118.3615',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad1596957'),
#   'rpt_id': '5812384',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '2020',
#   'area': '16',
#   'area_desc': 'Foothill',
#   'rd': '1617',
#   'age': '46',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '08',
#   'grp_description': 'Other Assaults',
#   'arst_typ_cd': 'M',
#   'charge': '243(A)PC',
#   'chrg_desc': 'BATTERY ON PERSON',
#   'location': '8600    FENWICK                      ST',
#   'crsst': nan,
#   'location_1': {'latitude': '34.262',
#    'longitude': '-118.3201',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad1596959'),
#   'rpt_id': '5812449',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '2250',
#   'area': '06',
#   'area_desc': 'Hollywood',
#   'rd': '0666',
#   'age': '33',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '08',
#   'grp_description': 'Other Assaults',
#   'arst_typ_cd': 'M',
#   'charge': '243(E)(1)PC',
#   'chrg_desc': 'BATT EX-SPOUSE/FIANCEE/PERSN W/DATING REL',
#   'location': '6200    DE LONGPRE                   AV',
#   'crsst': nan,
#   'location_1': {'latitude': '34.0962',
#    'longitude': '-118.3237',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad159695b'),
#   'rpt_id': '5812438',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '2200',
#   'area': '05',
#   'area_desc': 'Harbor',
#   'rd': '0529',
#   'age': '21',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '23',
#   'grp_description': 'Moving Traffic Violations',
#   'arst_typ_cd': 'F',
#   'charge': '2800.2(A)VC',
#   'chrg_desc': 'EVADE PO:DISREGARD SAFETY',
#   'location': 'GOODRICH',
#   'crsst': 'OPP',
#   'location_1': {'latitude': '33.7839',
#    'longitude': '-118.2381',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad159695d'),
#   'rpt_id': '5811909',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '1015',
#   'area': '02',
#   'area_desc': 'Rampart',
#   'rd': '0237',
#   'age': '38',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '16',
#   'grp_description': 'Narcotic Drug Laws',
#   'arst_typ_cd': 'M',
#   'charge': '11377(A)HS',
#   'chrg_desc': 'POSSESSION CONTROLLED SUBSTANCE',
#   'location': '2ND                          ST',
#   'crsst': 'TOLUCA                       ST',
#   'location_1': {'latitude': '34.0609',
#    'longitude': '-118.2586',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad159695f'),
#   'rpt_id': '5812321',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '2000',
#   'area': '01',
#   'area_desc': 'Central',
#   'rd': '0157',
#   'age': '27',
#   'sex_cd': 'M',
#   'descent_cd': 'B',
#   'chrg_grp_cd': '04',
#   'grp_description': 'Aggravated Assault',
#   'arst_typ_cd': 'M',
#   'charge': '273.5(A)PC',
#   'chrg_desc': 'CORPORAL INJURY ON SPOUSE/COHABITANT/ETC',
#   'location': '5TH                          ST',
#   'crsst': 'TOWNE',
#   'location_1': {'latitude': '34.043',
#    'longitude': '-118.242',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad1596961'),
#   'rpt_id': '5811815',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '0042',
#   'area': '14',
#   'area_desc': 'Pacific',
#   'rd': '1479',
#   'age': '55',
#   'sex_cd': 'M',
#   'descent_cd': 'B',
#   'chrg_grp_cd': '22',
#   'grp_description': 'Driving Under Influence',
#   'arst_typ_cd': 'M',
#   'charge': '23152(A)VC',
#   'chrg_desc': 'DRUNK DRIVING ALCOHOL/DRUGS',
#   'location': '405 FWY',
#   'crsst': 'LATIJERA',
#   'location_1': {'latitude': '33.9654',
#    'longitude': '-118.3783',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad1596963'),
#   'rpt_id': '5812436',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '2120',
#   'area': '13',
#   'area_desc': 'Newton',
#   'rd': '1363',
#   'age': '27',
#   'sex_cd': 'F',
#   'descent_cd': 'B',
#   'chrg_grp_cd': '23',
#   'grp_description': 'Moving Traffic Violations',
#   'arst_typ_cd': 'M',
#   'charge': '14601.1AVC',
#   'chrg_desc': 'DRIVE W/LIC SUSPEND/REVOKE 4 OTHER REASON',
#   'location': '49TH                         PL',
#   'crsst': 'WADSWORTH',
#   'location_1': {'latitude': '33.9985',
#    'longitude': '-118.2587',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad1596965'),
#   'rpt_id': '5811960',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '1315',
#   'area': '06',
#   'area_desc': 'Hollywood',
#   'rd': '0644',
#   'age': '41',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '24',
#   'grp_description': 'Miscellaneous Other Violations',
#   'arst_typ_cd': 'O',
#   'charge': '3454(C)PC',
#   'chrg_desc': 'FLASH INCARCERATION',
#   'location': 'LA BREA',
#   'crsst': 'SUNSET',
#   'location_1': {'latitude': '34.098',
#    'longitude': '-118.3441',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad1596967'),
#   'rpt_id': '191617260',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '1950',
#   'area': '16',
#   'area_desc': 'Foothill',
#   'rd': '1641',
#   'age': '44',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '18',
#   'grp_description': 'Drunkeness',
#   'arst_typ_cd': 'M',
#   'charge': '41.27DLAMC',
#   'chrg_desc': 'POSS ALCH BEV ON POSTED PREM',
#   'location': 'REMICK',
#   'crsst': 'OSBORNE',
#   'location_1': {'latitude': '34.2545',
#    'longitude': '-118.4272',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad1596969'),
#   'rpt_id': '190901021',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '1210',
#   'area': '09',
#   'area_desc': 'Van Nuys',
#   'rd': '0964',
#   'age': '23',
#   'sex_cd': 'F',
#   'descent_cd': 'X',
#   'chrg_grp_cd': '20',
#   'grp_description': 'Disorderly Conduct',
#   'arst_typ_cd': 'M',
#   'charge': '647(C)PC',
#   'chrg_desc': 'BEGGING',
#   'location': '14100    RIVERSIDE                    DR',
#   'crsst': nan,
#   'location_1': {'latitude': '34.1576',
#    'longitude': '-118.44',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad159696b'),
#   'rpt_id': '190128527',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '1100',
#   'area': '01',
#   'area_desc': 'Central',
#   'rd': '0158',
#   'age': '45',
#   'sex_cd': 'M',
#   'descent_cd': 'B',
#   'chrg_grp_cd': '18',
#   'grp_description': 'Drunkeness',
#   'arst_typ_cd': 'M',
#   'charge': '41.27CLAMC',
#   'chrg_desc': 'DRINKING IN PUBLIC',
#   'location': '7TH',
#   'crsst': 'KOHLER',
#   'location_1': {'latitude': '34.0377',
#    'longitude': '-118.2425',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad159696d'),
#   'rpt_id': '5812250',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '1715',
#   'area': '21',
#   'area_desc': 'Topanga',
#   'rd': '2155',
#   'age': '37',
#   'sex_cd': 'M',
#   'descent_cd': 'O',
#   'chrg_grp_cd': '04',
#   'grp_description': 'Aggravated Assault',
#   'arst_typ_cd': 'F',
#   'charge': '273A(A)PC',
#   'chrg_desc': 'CRUEL TO CHILD LIKELY TO PROD GBI/DEATH',
#   'location': '22100    ERWIN                        ST',
#   'crsst': nan,
#   'location_1': {'latitude': '34.1829',
#    'longitude': '-118.6077',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad159696f'),
#   'rpt_id': '5812260',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '1610',
#   'area': '04',
#   'area_desc': 'Hollenbeck',
#   'rd': '0462',
#   'age': '25',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '08',
#   'grp_description': 'Other Assaults',
#   'arst_typ_cd': 'M',
#   'charge': '243(E)(1)PC',
#   'chrg_desc': 'BATT EX-SPOUSE/FIANCEE/PERSN W/DATING REL',
#   'location': 'BOYLE                        AV',
#   'crsst': 'HOLLENBECK                   DR',
#   'location_1': {'latitude': '34.0379',
#    'longitude': '-118.2194',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad1596971'),
#   'rpt_id': '5811842',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '0340',
#   'area': '12',
#   'area_desc': '77th Street',
#   'rd': '1257',
#   'age': '60',
#   'sex_cd': 'M',
#   'descent_cd': 'B',
#   'chrg_grp_cd': '08',
#   'grp_description': 'Other Assaults',
#   'arst_typ_cd': 'F',
#   'charge': '422(A)PC',
#   'chrg_desc': 'TERRORIZE CAUSING FEAR',
#   'location': '500 W  76TH                         ST',
#   'crsst': nan,
#   'location_1': {'latitude': '33.9708',
#    'longitude': '-118.2827',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad1596973'),
#   'rpt_id': '191424716',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '1550',
#   'area': '14',
#   'area_desc': 'Pacific',
#   'rd': '1443',
#   'age': '48',
#   'sex_cd': 'M',
#   'descent_cd': 'B',
#   'chrg_grp_cd': '16',
#   'grp_description': 'Narcotic Drug Laws',
#   'arst_typ_cd': 'M',
#   'charge': '11364HS',
#   'chrg_desc': 'POSSESSION CNTL SUBSTANCE PARAPHERNALIA',
#   'location': '2400    PENMAR                       AV',
#   'crsst': nan,
#   'location_1': {'latitude': '33.9948',
#    'longitude': '-118.4511',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad1596975'),
#   'rpt_id': '190325616',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '1310',
#   'area': '03',
#   'area_desc': 'Southwest',
#   'rd': '0374',
#   'age': '48',
#   'sex_cd': 'M',
#   'descent_cd': 'B',
#   'chrg_grp_cd': nan,
#   'grp_description': nan,
#   'arst_typ_cd': 'M',
#   'charge': '11364 H&S',
#   'chrg_desc': nan,
#   'location': '3800    ARLINGTON                    AV',
#   'crsst': nan,
#   'location_1': {'latitude': '34.0183',
#    'longitude': '-118.3182',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad1596977'),
#   'rpt_id': '5811894',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '0930',
#   'area': '01',
#   'area_desc': 'Central',
#   'rd': '0152',
#   'age': '28',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '16',
#   'grp_description': 'Narcotic Drug Laws',
#   'arst_typ_cd': 'M',
#   'charge': '11377(A)HS',
#   'chrg_desc': 'POSSESSION CONTROLLED SUBSTANCE',
#   'location': '600 S  FIGUEROA                     ST',
#   'crsst': nan,
#   'location_1': {'latitude': '34.0509',
#    'longitude': '-118.2585',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad1596979'),
#   'rpt_id': '5812371',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '2040',
#   'area': '01',
#   'area_desc': 'Central',
#   'rd': '0158',
#   'age': '48',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '06',
#   'grp_description': 'Larceny',
#   'arst_typ_cd': 'M',
#   'charge': '484(A)PC',
#   'chrg_desc': 'GRAND THEFT (OVER $400)',
#   'location': '7TH',
#   'crsst': 'GLADYS',
#   'location_1': {'latitude': '34.0385',
#    'longitude': '-118.2437',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad159697b'),
#   'rpt_id': '5811755',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '0145',
#   'area': '06',
#   'area_desc': 'Hollywood',
#   'rd': '0676',
#   'age': '35',
#   'sex_cd': 'M',
#   'descent_cd': 'B',
#   'chrg_grp_cd': '08',
#   'grp_description': 'Other Assaults',
#   'arst_typ_cd': 'M',
#   'charge': '243(A)PC',
#   'chrg_desc': 'BATTERY ON PERSON',
#   'location': 'LILLIAN',
#   'crsst': 'MELROSE',
#   'location_1': {'latitude': '34.0835',
#    'longitude': '-118.3277',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad159697d'),
#   'rpt_id': '5811995',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '1300',
#   'area': '20',
#   'area_desc': 'Olympic',
#   'rd': '2055',
#   'age': '58',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '08',
#   'grp_description': 'Other Assaults',
#   'arst_typ_cd': 'F',
#   'charge': '69PC',
#   'chrg_desc': 'OBSTRUCT/RESIST EXECUTIVE OFFICER',
#   'location': 'OLYMPIC',
#   'crsst': 'MARIPOSA',
#   'location_1': {'latitude': '34.0526',
#    'longitude': '-118.2989',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad159697f'),
#   'rpt_id': '5812498',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '2245',
#   'area': '08',
#   'area_desc': 'West LA',
#   'rd': '0849',
#   'age': '28',
#   'sex_cd': 'M',
#   'descent_cd': 'W',
#   'chrg_grp_cd': '24',
#   'grp_description': 'Miscellaneous Other Violations',
#   'arst_typ_cd': 'F',
#   'charge': '594(A)(3)PC',
#   'chrg_desc': 'DESTROY PROPERTY',
#   'location': '900 S  LE DOUX                      RD',
#   'crsst': nan,
#   'location_1': {'latitude': '34.0583',
#    'longitude': '-118.3799',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad1596981'),
#   'rpt_id': '5811944',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '1200',
#   'area': '03',
#   'area_desc': 'Southwest',
#   'rd': '0395',
#   'age': '37',
#   'sex_cd': 'M',
#   'descent_cd': 'B',
#   'chrg_grp_cd': '08',
#   'grp_description': 'Other Assaults',
#   'arst_typ_cd': 'M',
#   'charge': '148(A)(1)PC',
#   'chrg_desc': 'OBSTRUCT/ETC PUB OFCR/ETC',
#   'location': '1500 W  MARTIN LUTHER KING JR        BL',
#   'crsst': nan,
#   'location_1': {'latitude': '34.0109',
#    'longitude': '-118.3112',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad1596983'),
#   'rpt_id': '5812501',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '1920',
#   'area': '08',
#   'area_desc': 'West LA',
#   'rd': '0893',
#   'age': '47',
#   'sex_cd': 'M',
#   'descent_cd': 'W',
#   'chrg_grp_cd': '16',
#   'grp_description': 'Narcotic Drug Laws',
#   'arst_typ_cd': 'M',
#   'charge': '11350(A)HS',
#   'chrg_desc': 'POSSESSION OF CONTROLLED SUBSTANCE',
#   'location': '11200    EXPOSITION                   BL',
#   'crsst': nan,
#   'location_1': {'latitude': '34.0352',
#    'longitude': '-118.4341',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad1596985'),
#   'rpt_id': '5812538',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '2300',
#   'area': '07',
#   'area_desc': 'Wilshire',
#   'rd': '0701',
#   'age': '42',
#   'sex_cd': 'M',
#   'descent_cd': 'W',
#   'chrg_grp_cd': '16',
#   'grp_description': 'Narcotic Drug Laws',
#   'arst_typ_cd': 'M',
#   'charge': '11377(A)HS',
#   'chrg_desc': 'POSSESSION CONTROLLED SUBSTANCE',
#   'location': 'CLINTON',
#   'crsst': 'EDINBURGH',
#   'location_1': {'latitude': '34.0816',
#    'longitude': '-118.3637',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad1596987'),
#   'rpt_id': '191424957',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '0310',
#   'area': '14',
#   'area_desc': 'Pacific',
#   'rd': '1494',
#   'age': '63',
#   'sex_cd': 'M',
#   'descent_cd': 'O',
#   'chrg_grp_cd': '08',
#   'grp_description': 'Other Assaults',
#   'arst_typ_cd': 'M',
#   'charge': '243(A)PC',
#   'chrg_desc': 'BATTERY ON PERSON',
#   'location': '400    WORLD WAY',
#   'crsst': nan,
#   'location_1': {'latitude': '33.9433',
#    'longitude': '-118.4072',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad1596989'),
#   'rpt_id': '190819081',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '1700',
#   'area': '08',
#   'area_desc': 'West LA',
#   'rd': '0855',
#   'age': '62',
#   'sex_cd': 'F',
#   'descent_cd': 'O',
#   'chrg_grp_cd': '06',
#   'grp_description': 'Larceny',
#   'arst_typ_cd': 'M',
#   'charge': '459.5PC',
#   'chrg_desc': 'SHOPLIFTING',
#   'location': '1700    WESTWOOD                     BL',
#   'crsst': nan,
#   'location_1': {'latitude': '34.0519',
#    'longitude': '-118.4388',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad159698b'),
#   'rpt_id': '5811835',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '0245',
#   'area': '05',
#   'area_desc': 'Harbor',
#   'rd': '0587',
#   'age': '46',
#   'sex_cd': 'F',
#   'descent_cd': 'W',
#   'chrg_grp_cd': '12',
#   'grp_description': 'Weapon (carry/poss)',
#   'arst_typ_cd': 'M',
#   'charge': '417(A)(1)PC',
#   'chrg_desc': 'EXHIBIT/DRAW DEADLY WEAPON NOT A FIREARM',
#   'location': '2500    CAROLINA                     ST',
#   'crsst': nan,
#   'location_1': {'latitude': '33.7212',
#    'longitude': '-118.2909',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad159698d'),
#   'rpt_id': '190128530',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '1129',
#   'area': '01',
#   'area_desc': 'Central',
#   'rd': '0158',
#   'age': '45',
#   'sex_cd': 'M',
#   'descent_cd': 'B',
#   'chrg_grp_cd': '17',
#   'grp_description': 'Liquor Laws',
#   'arst_typ_cd': 'I',
#   'charge': '25620ABP',
#   'chrg_desc': 'DRINKING ALCOHOL*******',
#   'location': '8TH',
#   'crsst': 'MERCHANT',
#   'location_1': {'latitude': '34.0395',
#    'longitude': '-118.2405',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad159698f'),
#   'rpt_id': '5811885',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '1025',
#   'area': '09',
#   'area_desc': 'Van Nuys',
#   'rd': '0935',
#   'age': '32',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '24',
#   'grp_description': 'Miscellaneous Other Violations',
#   'arst_typ_cd': 'M',
#   'charge': '166(C)(1)PC',
#   'chrg_desc': 'VIOL DOMESTIC VIOL PROTECT/STAY AWAY ORD',
#   'location': '14400    ERWIN                        ST',
#   'crsst': nan,
#   'location_1': {'latitude': '34.1837',
#    'longitude': '-118.4465',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad1596991'),
#   'rpt_id': '190222608',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '0005',
#   'area': '02',
#   'area_desc': 'Rampart',
#   'rd': '0218',
#   'age': '15',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '24',
#   'grp_description': 'Miscellaneous Other Violations',
#   'arst_typ_cd': 'M',
#   'charge': '45.03LAMC',
#   'chrg_desc': 'CURFEW - JUV ONLY',
#   'location': 'PARK                         DR',
#   'crsst': 'ECHO PARK',
#   'location_1': {'latitude': '34.0748',
#    'longitude': '-118.2586',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad1596993'),
#   'rpt_id': '5812354',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '2030',
#   'area': '21',
#   'area_desc': 'Topanga',
#   'rd': '2129',
#   'age': '39',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '24',
#   'grp_description': 'Miscellaneous Other Violations',
#   'arst_typ_cd': 'F',
#   'charge': '3455(B)1PC',
#   'chrg_desc': 'WARRANT-PETITION TO REVOKE COMMUNITY SUPVN',
#   'location': 'ROSCOE',
#   'crsst': 'HATILLO',
#   'location_1': {'latitude': '34.2203',
#    'longitude': '-118.5656',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad1596995'),
#   'rpt_id': '5811816',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '0530',
#   'area': '09',
#   'area_desc': 'Van Nuys',
#   'rd': '0901',
#   'age': '32',
#   'sex_cd': 'F',
#   'descent_cd': 'B',
#   'chrg_grp_cd': '13',
#   'grp_description': 'Prostitution/Allied',
#   'arst_typ_cd': 'M',
#   'charge': '653.22(A)PC',
#   'chrg_desc': 'LOITER:INTENT:PROSTITUTION',
#   'location': 'SEPULVEDA',
#   'crsst': 'HART',
#   'location_1': {'latitude': '34.2085',
#    'longitude': '-118.4698',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad1596997'),
#   'rpt_id': '5812278',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '1815',
#   'area': '02',
#   'area_desc': 'Rampart',
#   'rd': '0246',
#   'age': '32',
#   'sex_cd': 'M',
#   'descent_cd': 'W',
#   'chrg_grp_cd': '24',
#   'grp_description': 'Miscellaneous Other Violations',
#   'arst_typ_cd': 'M',
#   'charge': '853.7PC',
#   'chrg_desc': 'FTA AFTER WRITTEN PROMISE',
#   'location': '600 S  ALVARADO                     ST',
#   'crsst': nan,
#   'location_1': {'latitude': '34.0596',
#    'longitude': '-118.2749',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad1596999'),
#   'rpt_id': '191521479',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '0850',
#   'area': '15',
#   'area_desc': 'N Hollywood',
#   'rd': '1546',
#   'age': '26',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': nan,
#   'grp_description': nan,
#   'arst_typ_cd': 'I',
#   'charge': '6344D4',
#   'chrg_desc': nan,
#   'location': 'CHANDLER',
#   'crsst': 'TUJUNGA',
#   'location_1': {'latitude': '34.1629',
#    'longitude': '-118.3848',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad159699b'),
#   'rpt_id': '5811876',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '0745',
#   'area': '18',
#   'area_desc': 'Southeast',
#   'rd': '1802',
#   'age': '41',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '15',
#   'grp_description': 'Against Family/Child',
#   'arst_typ_cd': 'M',
#   'charge': '273.6(A)PC',
#   'chrg_desc': 'DISOBEY DOMESTIC RELATIONS COURT ORDER',
#   'location': '100 W  92ND                         ST',
#   'crsst': nan,
#   'location_1': {'latitude': '33.9529',
#    'longitude': '-118.2739',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad159699d'),
#   'rpt_id': '5811791',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '0340',
#   'area': '04',
#   'area_desc': 'Hollenbeck',
#   'rd': '0418',
#   'age': '37',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '16',
#   'grp_description': 'Narcotic Drug Laws',
#   'arst_typ_cd': 'M',
#   'charge': '11364(A)HS',
#   'chrg_desc': 'POSS DEVICE/INSTRUMT/PARAPHERNALIA',
#   'location': '4000    COLLIS                       AV',
#   'crsst': nan,
#   'location_1': {'latitude': '34.0928',
#    'longitude': '-118.1818',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad159699f'),
#   'rpt_id': '5811722',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '0001',
#   'area': '20',
#   'area_desc': 'Olympic',
#   'rd': '2046',
#   'age': '31',
#   'sex_cd': 'M',
#   'descent_cd': 'O',
#   'chrg_grp_cd': '04',
#   'grp_description': 'Aggravated Assault',
#   'arst_typ_cd': 'F',
#   'charge': '273.5(A)PC',
#   'chrg_desc': 'CORPORAL INJURY ON SPOUSE/COHABITANT/ETC',
#   'location': '2900    SAN MARINO                   ST',
#   'crsst': nan,
#   'location_1': {'latitude': '34.0561',
#    'longitude': '-118.2941',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad15969a1'),
#   'rpt_id': '5811808',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '0230',
#   'area': '03',
#   'area_desc': 'Southwest',
#   'rd': '0396',
#   'age': '55',
#   'sex_cd': 'M',
#   'descent_cd': 'B',
#   'chrg_grp_cd': '15',
#   'grp_description': 'Against Family/Child',
#   'arst_typ_cd': 'M',
#   'charge': '273.6(A)PC',
#   'chrg_desc': 'DISOBEY DOMESTIC RELATIONS COURT ORDER',
#   'location': '800 W  40TH                         PL',
#   'crsst': nan,
#   'location_1': {'latitude': '34.0101',
#    'longitude': '-118.2872',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad15969a3'),
#   'rpt_id': '190518842',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '1055',
#   'area': '05',
#   'area_desc': 'Harbor',
#   'rd': '0563',
#   'age': '27',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '24',
#   'grp_description': 'Miscellaneous Other Violations',
#   'arst_typ_cd': 'M',
#   'charge': '308(A)PC',
#   'chrg_desc': 'GIVE TOBACCO/SMOKG PARAPHERNALIA MINR <18',
#   'location': '1000 S  GAFFEY                       ST',
#   'crsst': nan,
#   'location_1': {'latitude': '33.7352',
#    'longitude': '-118.2923',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad15969a5'),
#   'rpt_id': '5812230',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '1510',
#   'area': '18',
#   'area_desc': 'Southeast',
#   'rd': '1842',
#   'age': '24',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '08',
#   'grp_description': 'Other Assaults',
#   'arst_typ_cd': 'F',
#   'charge': '422(A)PC',
#   'chrg_desc': 'TERRORIZE CAUSING FEAR',
#   'location': '200 E  110TH                        ST',
#   'crsst': nan,
#   'location_1': {'latitude': '33.9357',
#    'longitude': '-118.2717',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad15969a7'),
#   'rpt_id': '5812456',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '2310',
#   'area': '07',
#   'area_desc': 'Wilshire',
#   'rd': '0784',
#   'age': '41',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '24',
#   'grp_description': 'Miscellaneous Other Violations',
#   'arst_typ_cd': 'M',
#   'charge': '466PC',
#   'chrg_desc': 'POSSESSION BURGLARY TOOLS',
#   'location': '21ST',
#   'crsst': 'REDONDO',
#   'location_1': {'latitude': '34.0393',
#    'longitude': '-118.3536',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad15969a9'),
#   'rpt_id': '5812401',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '2035',
#   'area': '01',
#   'area_desc': 'Central',
#   'rd': '0162',
#   'age': '43',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '06',
#   'grp_description': 'Larceny',
#   'arst_typ_cd': 'M',
#   'charge': '490.2PC',
#   'chrg_desc': 'PETTY THEFT',
#   'location': '700 W  7TH                          ST',
#   'crsst': nan,
#   'location_1': {'latitude': '34.048',
#    'longitude': '-118.2577',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad15969ab'),
#   'rpt_id': '5811915',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '1025',
#   'area': '12',
#   'area_desc': '77th Street',
#   'rd': '1268',
#   'age': '24',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '07',
#   'grp_description': 'Vehicle Theft',
#   'arst_typ_cd': 'F',
#   'charge': '10851(A)VC',
#   'chrg_desc': "TAKE VEHICLE W/O OWNER'S CONSENT",
#   'location': '86TH                         PL',
#   'crsst': 'BROADWAY                     AV',
#   'location_1': {'latitude': '33.964',
#    'longitude': '-118.2739',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad15969ad'),
#   'rpt_id': '5811900',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '0850',
#   'area': '05',
#   'area_desc': 'Harbor',
#   'rd': '0517',
#   'age': '41',
#   'sex_cd': 'F',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '24',
#   'grp_description': 'Miscellaneous Other Violations',
#   'arst_typ_cd': 'F',
#   'charge': '3455(B)1PC',
#   'chrg_desc': 'WARRANT-PETITION TO REVOKE COMMUNITY SUPVN',
#   'location': '1200    EUBANK                       AV',
#   'crsst': nan,
#   'location_1': {'latitude': '33.787',
#    'longitude': '-118.2555',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad15969af'),
#   'rpt_id': '5812368',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '2045',
#   'area': '03',
#   'area_desc': 'Southwest',
#   'rd': '0374',
#   'age': '30',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '24',
#   'grp_description': 'Miscellaneous Other Violations',
#   'arst_typ_cd': 'F',
#   'charge': '594(A)(1)PC',
#   'chrg_desc': 'DEFACE PROPERTY',
#   'location': 'MARTIN LUTHER KI',
#   'crsst': 'KANSAS                       ST',
#   'location_1': {'latitude': '34.0148',
#    'longitude': '-118.3222',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad15969b1'),
#   'rpt_id': '5812291',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '1745',
#   'area': '11',
#   'area_desc': 'Northeast',
#   'rd': '1147',
#   'age': '47',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '08',
#   'grp_description': 'Other Assaults',
#   'arst_typ_cd': 'M',
#   'charge': '243(A)PC',
#   'chrg_desc': 'BATTERY ON PERSON',
#   'location': '3400    ISABEL                       DR',
#   'crsst': nan,
#   'location_1': {'latitude': '34.1043',
#    'longitude': '-118.2275',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad15969b3'),
#   'rpt_id': '5811824',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '0308',
#   'area': '12',
#   'area_desc': '77th Street',
#   'rd': '1256',
#   'age': '25',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '22',
#   'grp_description': 'Driving Under Influence',
#   'arst_typ_cd': 'M',
#   'charge': '23152(A)VC',
#   'chrg_desc': 'DRUNK DRIVING ALCOHOL/DRUGS',
#   'location': '75TH',
#   'crsst': 'FIGUEROA',
#   'location_1': {'latitude': '33.9717',
#    'longitude': '-118.2827',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b609303caffad15969b5'),
#   'rpt_id': '5812249',
#   'arst_date': datetime.datetime(2019, 12, 1, 0, 0),
#   'time': '1530',
#   'area': '06',
#   'area_desc': 'Hollywood',
#   'rd': '0668',
#   'age': '31',
#   'sex_cd': 'M',
#   'descent_cd': 'B',
#   'chrg_grp_cd': '16',
#   'grp_description': 'Narcotic Drug Laws',
#   'arst_typ_cd': 'M',
#   'charge': '11377(A)HS',
#   'chrg_desc': 'POSSESSION CONTROLLED SUBSTANCE',
#   'location': '5600    FERNWOOD                     AV',
#   'crsst': nan,
#   'location_1': {'latitude': '34.0958',
# ...
#   'location_1': {'latitude': '34.1552',
#    'longitude': '-118.4749',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b60b303caffad15970c2'),
#   'rpt_id': '192119500',
#   'arst_date': datetime.datetime(2019, 12, 7, 0, 0),
#   'time': '0950',
#   'area': '21',
#   'area_desc': 'Topanga',
#   'rd': '2146',
#   'age': '48',
#   'sex_cd': 'M',
#   'descent_cd': 'W',
#   'chrg_grp_cd': '16',
#   'grp_description': 'Narcotic Drug Laws',
#   'arst_typ_cd': 'M',
#   'charge': '11377(A)HS',
#   'chrg_desc': 'POSSESSION CONTROLLED SUBSTANCE',
#   'location': 'VANOWEN',
#   'crsst': 'VARIEL',
#   'location_1': {'latitude': '34.1938',
#    'longitude': '-118.5928',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b60b303caffad15970c4'),
#   'rpt_id': '5816611',
#   'arst_date': datetime.datetime(2019, 12, 7, 0, 0),
#   'time': '0135',
#   'area': '14',
#   'area_desc': 'Pacific',
#   'rd': '1459',
#   'age': '22',
#   'sex_cd': 'F',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '22',
#   'grp_description': 'Driving Under Influence',
#   'arst_typ_cd': 'M',
#   'charge': '23152(A)VC',
#   'chrg_desc': 'DRUNK DRIVING ALCOHOL/DRUGS',
#   'location': 'PURDUE                       AV',
#   'crsst': 'UTOPIA                       AV',
#   'location_1': {'latitude': '33.9965',
#    'longitude': '-118.4053',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b60b303caffad15970c6'),
#   'rpt_id': '5816833',
#   'arst_date': datetime.datetime(2019, 12, 7, 0, 0),
#   'time': '0305',
#   'area': '10',
#   'area_desc': 'West Valley',
#   'rd': '1049',
#   'age': '47',
#   'sex_cd': 'F',
#   'descent_cd': 'O',
#   'chrg_grp_cd': '22',
#   'grp_description': 'Driving Under Influence',
#   'arst_typ_cd': 'M',
#   'charge': '23152(A)VC',
#   'chrg_desc': 'DRUNK DRIVING ALCOHOL/DRUGS',
#   'location': 'HAYVENHURST',
#   'crsst': 'BURBANK',
#   'location_1': {'latitude': '34.167',
#    'longitude': '-118.4923',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b60b303caffad15970c8'),
#   'rpt_id': '5816517',
#   'arst_date': datetime.datetime(2019, 12, 7, 0, 0),
#   'time': '0030',
#   'area': '20',
#   'area_desc': 'Olympic',
#   'rd': '2004',
#   'age': '59',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '13',
#   'grp_description': 'Prostitution/Allied',
#   'arst_typ_cd': 'M',
#   'charge': '647(B)PC',
#   'chrg_desc': 'PROSTITUTION',
#   'location': 'WESTERN                      AV',
#   'crsst': 'ELMWOOD',
#   'location_1': {'latitude': '34.0783',
#    'longitude': '-118.3092',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b60b303caffad15970ca'),
#   'rpt_id': '191425091',
#   'arst_date': datetime.datetime(2019, 12, 7, 0, 0),
#   'time': '1300',
#   'area': '14',
#   'area_desc': 'Pacific',
#   'rd': '1494',
#   'age': '34',
#   'sex_cd': 'F',
#   'descent_cd': 'B',
#   'chrg_grp_cd': '12',
#   'grp_description': 'Weapon (carry/poss)',
#   'arst_typ_cd': 'M',
#   'charge': '22210PC',
#   'chrg_desc': 'MFG/SELL/GIVE/LEND POSSES LEADED CANE/ETC',
#   'location': '600    WORLD                        WY',
#   'crsst': nan,
#   'location_1': {'latitude': '33.943',
#    'longitude': '-118.4035',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b60b303caffad15970cc'),
#   'rpt_id': '5816903',
#   'arst_date': datetime.datetime(2019, 12, 7, 0, 0),
#   'time': '0600',
#   'area': '19',
#   'area_desc': 'Mission',
#   'rd': '1994',
#   'age': '16',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': nan,
#   'grp_description': nan,
#   'arst_typ_cd': 'D',
#   'charge': '300(A)WI',
#   'chrg_desc': nan,
#   'location': '8200    BRIMFIELD',
#   'crsst': nan,
#   'location_1': {'latitude': '34.2198',
#    'longitude': '-118.4586',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b60b303caffad15970ce'),
#   'rpt_id': '190920909',
#   'arst_date': datetime.datetime(2019, 12, 7, 0, 0),
#   'time': '0720',
#   'area': '09',
#   'area_desc': 'Van Nuys',
#   'rd': '0914',
#   'age': '48',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '13',
#   'grp_description': 'Prostitution/Allied',
#   'arst_typ_cd': 'M',
#   'charge': '647(B)(2)PC',
#   'chrg_desc': 'ENGAGE/SOLICIT SEX FOR MONEY/ETC',
#   'location': 'SEPULVEDA                    BL',
#   'crsst': 'VOSE                         ST',
#   'location_1': {'latitude': '34.1985',
#    'longitude': '-118.4662',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b60b303caffad15970d0'),
#   'rpt_id': '5816563',
#   'arst_date': datetime.datetime(2019, 12, 7, 0, 0),
#   'time': '0040',
#   'area': '14',
#   'area_desc': 'Pacific',
#   'rd': '1494',
#   'age': '28',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '16',
#   'grp_description': 'Narcotic Drug Laws',
#   'arst_typ_cd': 'M',
#   'charge': '11350(A)HS',
#   'chrg_desc': 'POSSESSION OF CONTROLLED SUBSTANCE',
#   'location': '300    WORLD                        WY',
#   'crsst': nan,
#   'location_1': {'latitude': '33.944',
#    'longitude': '-118.4073',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b60b303caffad15970d2'),
#   'rpt_id': '5816616',
#   'arst_date': datetime.datetime(2019, 12, 7, 0, 0),
#   'time': '0220',
#   'area': '03',
#   'area_desc': 'Southwest',
#   'rd': '0393',
#   'age': '35',
#   'sex_cd': 'M',
#   'descent_cd': 'B',
#   'chrg_grp_cd': '22',
#   'grp_description': 'Driving Under Influence',
#   'arst_typ_cd': 'M',
#   'charge': '23152(A)VC',
#   'chrg_desc': 'DRUNK DRIVING ALCOHOL/DRUGS',
#   'location': '43RD                         PL',
#   'crsst': 'WESTERN',
#   'location_1': {'latitude': '34.0074',
#    'longitude': '-118.329',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b60b303caffad15970d4'),
#   'rpt_id': '5816514',
#   'arst_date': datetime.datetime(2019, 12, 7, 0, 0),
#   'time': '0015',
#   'area': '20',
#   'area_desc': 'Olympic',
#   'rd': '2004',
#   'age': '37',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '13',
#   'grp_description': 'Prostitution/Allied',
#   'arst_typ_cd': 'M',
#   'charge': '647(B)PC',
#   'chrg_desc': 'PROSTITUTION',
#   'location': 'ELMWOOD',
#   'crsst': 'WESTERN                      AV',
#   'location_1': {'latitude': '34.0799',
#    'longitude': '-118.3068',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b60b303caffad15970d6'),
#   'rpt_id': '5816831',
#   'arst_date': datetime.datetime(2019, 12, 7, 0, 0),
#   'time': '0257',
#   'area': '14',
#   'area_desc': 'Pacific',
#   'rd': '1401',
#   'age': '23',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '22',
#   'grp_description': 'Driving Under Influence',
#   'arst_typ_cd': 'M',
#   'charge': '23152(A)VC',
#   'chrg_desc': 'DRUNK DRIVING ALCOHOL/DRUGS',
#   'location': 'CRENSHAW                     BL',
#   'crsst': 'SANTA MONICA                 FY',
#   'location_1': {'latitude': '34.0247',
#    'longitude': '-118.4454',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b60b303caffad15970d8'),
#   'rpt_id': '5816592',
#   'arst_date': datetime.datetime(2019, 12, 7, 0, 0),
#   'time': '0230',
#   'area': '01',
#   'area_desc': 'Central',
#   'rd': '0191',
#   'age': '24',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '22',
#   'grp_description': 'Driving Under Influence',
#   'arst_typ_cd': 'M',
#   'charge': '23152(A)VC',
#   'chrg_desc': 'DRUNK DRIVING ALCOHOL/DRUGS',
#   'location': '10                           FY',
#   'crsst': 'MAPLE                        AV',
#   'location_1': {'latitude': '34.0388',
#    'longitude': '-118.2717',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b60b303caffad15970da'),
#   'rpt_id': '5816959',
#   'arst_date': datetime.datetime(2019, 12, 7, 0, 0),
#   'time': '1250',
#   'area': '01',
#   'area_desc': 'Central',
#   'rd': '0127',
#   'age': '23',
#   'sex_cd': 'F',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '22',
#   'grp_description': 'Driving Under Influence',
#   'arst_typ_cd': 'M',
#   'charge': '23152(B)VC',
#   'chrg_desc': 'DRUNK DRIVING .10 OR ABOVE',
#   'location': '100 N  LOS ANGELES                  ST',
#   'crsst': nan,
#   'location_1': {'latitude': '34.0515',
#    'longitude': '-118.2424',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b60b303caffad15970dc'),
#   'rpt_id': '5816911',
#   'arst_date': datetime.datetime(2019, 12, 7, 0, 0),
#   'time': '0830',
#   'area': '04',
#   'area_desc': 'Hollenbeck',
#   'rd': '0411',
#   'age': '45',
#   'sex_cd': 'F',
#   'descent_cd': 'W',
#   'chrg_grp_cd': '16',
#   'grp_description': 'Narcotic Drug Laws',
#   'arst_typ_cd': 'F',
#   'charge': '11379(A)HS',
#   'chrg_desc': 'TRANSPORT/SELL CONTROLLED SUBSTANCE',
#   'location': 'AVE 18',
#   'crsst': 'BARRANCA                     ST',
#   'location_1': {'latitude': '34.0747',
#    'longitude': '-118.2244',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b60b303caffad15970de'),
#   'rpt_id': '5816871',
#   'arst_date': datetime.datetime(2019, 12, 7, 0, 0),
#   'time': '0650',
#   'area': '01',
#   'area_desc': 'Central',
#   'rd': '0119',
#   'age': '31',
#   'sex_cd': 'M',
#   'descent_cd': 'B',
#   'chrg_grp_cd': '16',
#   'grp_description': 'Narcotic Drug Laws',
#   'arst_typ_cd': 'M',
#   'charge': '11377(A)HS',
#   'chrg_desc': 'POSSESSION CONTROLLED SUBSTANCE',
#   'location': '800 N  ALAMEDA                      ST',
#   'crsst': nan,
#   'location_1': {'latitude': '34.0563',
#    'longitude': '-118.2374',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'_id': ObjectId('5df2b83b303caffad159715c'),
#   'rpt_id': '5794612',
#   'arst_date': datetime.datetime(2019, 11, 8, 0, 0),
#   'time': '1930',
#   'area': '18',
#   'area_desc': 'Southeast',
#   'rd': '1862',
#   'age': '25',
#   'sex_cd': 'F',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '16',
#   'grp_description': 'Narcotic Drug Laws',
#   'arst_typ_cd': 'M',
#   'charge': '11359(B)HS',
#   'chrg_desc': 'POSSESS MARIJUANA FOR SALE',
#   'location': '11800 S  MAIN                         ST',
#   'location_1': {'latitude': '33.9265',
#    'longitude': '-118.2739',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'crsst': nan},
#  {'_id': ObjectId('5df2b83b303caffad159715e'),
#   'rpt_id': '5794611',
#   'arst_date': datetime.datetime(2019, 11, 8, 0, 0),
#   'time': '1900',
#   'area': '18',
#   'area_desc': 'Southeast',
#   'rd': '1862',
#   'age': '23',
#   'sex_cd': 'M',
#   'descent_cd': 'B',
#   'chrg_grp_cd': '16',
#   'grp_description': 'Narcotic Drug Laws',
#   'arst_typ_cd': 'M',
#   'charge': '11359(B)HS',
#   'chrg_desc': 'POSSESS MARIJUANA FOR SALE',
#   'location': '11800 S  MAIN                         ST',
#   'location_1': {'latitude': '33.9265',
#    'longitude': '-118.2739',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'crsst': nan},
#  {'_id': ObjectId('5df2b83b303caffad1597160'),
#   'rpt_id': '5794609',
#   'arst_date': datetime.datetime(2019, 11, 8, 0, 0),
#   'time': '1930',
#   'area': '18',
#   'area_desc': 'Southeast',
#   'rd': '1862',
#   'age': '29',
#   'sex_cd': 'M',
#   'descent_cd': 'B',
#   'chrg_grp_cd': '16',
#   'grp_description': 'Narcotic Drug Laws',
#   'arst_typ_cd': 'M',
#   'charge': '11359(B)HS',
#   'chrg_desc': 'POSSESS MARIJUANA FOR SALE',
#   'location': '11800 S  MAIN                         ST',
#   'location_1': {'latitude': '33.9265',
#    'longitude': '-118.2739',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'crsst': nan},
#  {'_id': ObjectId('5df2b83b303caffad1597162'),
#   'rpt_id': '5794604',
#   'arst_date': datetime.datetime(2019, 11, 8, 0, 0),
#   'time': '2355',
#   'area': '09',
#   'area_desc': 'Van Nuys',
#   'rd': '0937',
#   'age': '43',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '04',
#   'grp_description': 'Aggravated Assault',
#   'arst_typ_cd': 'F',
#   'charge': '273.5(A)PC',
#   'chrg_desc': 'CORPORAL INJURY ON SPOUSE/COHABITANT/ETC',
#   'location': '14000    BESSEMER                     ST',
#   'location_1': {'latitude': '34.1813',
#    'longitude': '-118.4377',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'crsst': nan},
#  {'_id': ObjectId('5df2b83b303caffad1597164'),
#   'rpt_id': '5794601',
#   'arst_date': datetime.datetime(2019, 11, 8, 0, 0),
#   'time': '1930',
#   'area': '18',
#   'area_desc': 'Southeast',
#   'rd': '1862',
#   'age': '41',
#   'sex_cd': 'F',
#   'descent_cd': 'B',
#   'chrg_grp_cd': '16',
#   'grp_description': 'Narcotic Drug Laws',
#   'arst_typ_cd': 'M',
#   'charge': '11359(B)HS',
#   'chrg_desc': 'POSSESS MARIJUANA FOR SALE',
#   'location': '11800 S  MAIN                         ST',
#   'location_1': {'latitude': '33.9265',
#    'longitude': '-118.2739',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'crsst': nan},
#  {'_id': ObjectId('5df2b83b303caffad1597166'),
#   'rpt_id': '5794597',
#   'arst_date': datetime.datetime(2019, 11, 8, 0, 0),
#   'time': '1900',
#   'area': '18',
#   'area_desc': 'Southeast',
#   'rd': '1862',
#   'age': '22',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '16',
#   'grp_description': 'Narcotic Drug Laws',
#   'arst_typ_cd': 'M',
#   'charge': '11359(B)HS',
#   'chrg_desc': 'POSSESS MARIJUANA FOR SALE',
#   'location': '11800 S  MAIN                         ST',
#   'location_1': {'latitude': '33.9265',
#    'longitude': '-118.2739',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'crsst': nan},
#  {'_id': ObjectId('5df2b83b303caffad1597168'),
#   'rpt_id': '5794594',
#   'arst_date': datetime.datetime(2019, 11, 8, 0, 0),
#   'time': '2315',
#   'area': '02',
#   'area_desc': 'Rampart',
#   'rd': '0237',
#   'age': '24',
#   'sex_cd': 'M',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '12',
#   'grp_description': 'Weapon (carry/poss)',
#   'arst_typ_cd': 'F',
#   'charge': '21310PC',
#   'chrg_desc': 'CARRY CONCEALED ON PERSON DIRK OR DAGGER',
#   'location': '1400 W  2ND                          ST',
#   'location_1': {'latitude': '34.0609',
#    'longitude': '-118.26',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'crsst': nan},
#  {'_id': ObjectId('5df2b83b303caffad159716a'),
#   'rpt_id': '5794592',
#   'arst_date': datetime.datetime(2019, 11, 8, 0, 0),
#   'time': '1900',
#   'area': '18',
#   'area_desc': 'Southeast',
#   'rd': '1862',
#   'age': '22',
#   'sex_cd': 'F',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '16',
#   'grp_description': 'Narcotic Drug Laws',
#   'arst_typ_cd': 'M',
#   'charge': '11360(B)HS',
#   'chrg_desc': 'GIVE/TRANSPORT/ETC < 28.5 GRAMS MARIJUANA',
#   'location': '11800 S  MAIN                         ST',
#   'location_1': {'latitude': '33.9265',
#    'longitude': '-118.2739',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'crsst': nan},
#  {'_id': ObjectId('5df2b83b303caffad159716c'),
#   'rpt_id': '5794589',
#   'arst_date': datetime.datetime(2019, 11, 8, 0, 0),
#   'time': '1900',
#   'area': '18',
#   'area_desc': 'Southeast',
#   'rd': '1862',
#   'age': '24',
#   'sex_cd': 'F',
#   'descent_cd': 'H',
#   'chrg_grp_cd': '16',
#   'grp_description': 'Narcotic Drug Laws',
#   'arst_typ_cd': 'M',
#   'charge': '11359(B)HS',
#   'chrg_desc': 'POSSESS MARIJUANA FOR SALE',
#   'location': '11800 S  MAIN                         ST',
#   'location_1': {'latitude': '33.9265',
#    'longitude': '-118.2739',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'crsst': nan},
#  {'_id': ObjectId('5df2b83b303caffad159716e'),
#   'rpt_id': '5794578',
#   'arst_date': datetime.datetime(2019, 11, 8, 0, 0),
#   'time': '1930',
#   'area': '18',
#   'area_desc': 'Southeast',
#   'rd': '1862',
#   'age': '23',
#   'sex_cd': 'M',
#   'descent_cd': 'B',
#   'chrg_grp_cd': '16',
#   'grp_description': 'Narcotic Drug Laws',
#   'arst_typ_cd': 'M',
#   'charge': '11359(B)HS',
#   'chrg_desc': 'POSSESS MARIJUANA FOR SALE',
#   'location': '11800 S  MAIN                         ST',
#   'location_1': {'latitude': '33.9265',
#    'longitude': '-118.2739',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'crsst': nan},
#  ...]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268 entries, 0 to 267
# Data columns (total 17 columns):
# rpt_id             268 non-null object
# arst_date          268 non-null datetime64[ns]
# time               268 non-null object
# area               268 non-null object
# area_desc          268 non-null object
# rd                 268 non-null object
# age                268 non-null object
# sex_cd             268 non-null object
# descent_cd         268 non-null object
# chrg_grp_cd        243 non-null object
# grp_description    243 non-null object
# arst_typ_cd        268 non-null object
# charge             268 non-null object
# chrg_desc          244 non-null object
# location           268 non-null object
# location_1         268 non-null object
# crsst              112 non-null object
# dtypes: datetime64[ns](1), object(16)
# memory usage: 35.7+ KB

# %%
df
# Out:
#         rpt_id  arst_date  time area  area_desc    rd age sex_cd descent_cd  \
# 0      5794612 2019-11-08  1930   18  Southeast  1862  25      F          H
# 1      5794611 2019-11-08  1900   18  Southeast  1862  23      M          B
# 2      5794609 2019-11-08  1930   18  Southeast  1862  29      M          B
# 3      5794604 2019-11-08  2355   09   Van Nuys  0937  43      M          H
# 4      5794601 2019-11-08  1930   18  Southeast  1862  41      F          B
# ..         ...        ...   ...  ...        ...   ...  ..    ...        ...
# 263    5794296 2019-11-08  1950   20    Olympic  2099  51      M          H
# 264    5793744 2019-11-08  0425   08    West LA  0849  31      M          B
# 265  190221831 2019-11-08  2225   02    Rampart  0295  37      M          H
# 266  191423593 2019-11-08  1805   14    Pacific  1412  18      M          W
# 267    5794236 2019-11-08  0725   02    Rampart  0215  37      M          W
#
#     chrg_grp_cd          grp_description arst_typ_cd      charge  \
# 0            16       Narcotic Drug Laws           M  11359(B)HS
# 1            16       Narcotic Drug Laws           M  11359(B)HS
# 2            16       Narcotic Drug Laws           M  11359(B)HS
# 3            04       Aggravated Assault           F  273.5(A)PC
# 4            16       Narcotic Drug Laws           M  11359(B)HS
# ..          ...                      ...         ...         ...
# 263          16       Narcotic Drug Laws           M  11377(A)HS
# 264          04       Aggravated Assault           F  273.5(A)PC
# 265          18               Drunkeness           M  41.27CLAMC
# 266         NaN                      NaN           I   63.44B14A
# 267          22  Driving Under Influence           M  23152(F)VC
#
#                                     chrg_desc  \
# 0                  POSSESS MARIJUANA FOR SALE
# 1                  POSSESS MARIJUANA FOR SALE
# 2                  POSSESS MARIJUANA FOR SALE
# 3    CORPORAL INJURY ON SPOUSE/COHABITANT/ETC
# 4                  POSSESS MARIJUANA FOR SALE
# ..                                        ...
# 263           POSSESSION CONTROLLED SUBSTANCE
# 264  CORPORAL INJURY ON SPOUSE/COHABITANT/ETC
# 265                        DRINKING IN PUBLIC
# 266                                       NaN
# 267                           DUI OF ANY DRUG
#
#                                      location  \
# 0    11800 S  MAIN                         ST
# 1    11800 S  MAIN                         ST
# 2    11800 S  MAIN                         ST
# 3    14000    BESSEMER                     ST
# 4    11800 S  MAIN                         ST
# ..                                        ...
# 263                                      20TH
# 264   1200 S  HOLT                         AV
# 265   1200 W  VENICE                       BL
# 266   1200    PACIFIC                      AV
# 267           VENTURA                      FY
#
#                                             location_1        crsst
# 0    {'latitude': '33.9265', 'longitude': '-118.273...          NaN
# 1    {'latitude': '33.9265', 'longitude': '-118.273...          NaN
# 2    {'latitude': '33.9265', 'longitude': '-118.273...          NaN
# 3    {'latitude': '34.1813', 'longitude': '-118.437...          NaN
# 4    {'latitude': '33.9265', 'longitude': '-118.273...          NaN
# ..                                                 ...          ...
# 263  {'latitude': '34.0382', 'longitude': '-118.284...     ARAPAHOE
# 264  {'latitude': '34.0551', 'longitude': '-118.378...          NaN
# 265  {'latitude': '34.0424', 'longitude': '-118.281...          NaN
# 266  {'latitude': '33.99', 'longitude': '-118.474',...          NaN
# 267  {'latitude': '34.0757', 'longitude': '-118.277...  SILVER LAKE
#
# [268 rows x 17 columns]
